# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("pokemon.csv")

# %%
df.head()
# Out:
#    pokedex_id        name           genus generation type_1  type_2  \
# 0           1   bulbasaur    Seed Pokémon          I  grass  poison
# 1           2     ivysaur    Seed Pokémon          I  grass  poison
# 2           3    venusaur    Seed Pokémon          I  grass  poison
# 3           4  charmander  Lizard Pokémon          I   fire     NaN
# 4           5  charmeleon   Flame Pokémon          I   fire     NaN
#
#    num_types  hp  attack  defense  ...  \
# 0          2  45      49       49  ...
# 1          2  60      62       63  ...
# 2          2  80      82       83  ...
# 3          1  39      52       43  ...
# 4          1  58      64       58  ...
#
#                                           sprite_url  is_dual_type   bmi  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...          True  14.1
# 1  https://raw.githubusercontent.com/PokeAPI/spri...          True  13.0
# 2  https://raw.githubusercontent.com/PokeAPI/spri...          True  25.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 43 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   pokedex_id            1025 non-null   int64
#  1   name                  1025 non-null   str
#  2   genus                 1025 non-null   str
#  3   generation            1025 non-null   str
#  4   type_1                1025 non-null   str
#  5   type_2                526 non-null    str
#  6   num_types             1025 non-null   int64
#  7   hp                    1025 non-null   int64
#  8   attack                1025 non-null   int64
#  9   defense               1025 non-null   int64
#  10  sp_attack             1025 non-null   int64
#  11  sp_defense            1025 non-null   int64
#  12  speed                 1025 non-null   int64
#  13  base_stat_total       1025 non-null   int64
#  14  height_m              1025 non-null   float64
# ...
